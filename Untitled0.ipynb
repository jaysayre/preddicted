# %%
import nltk
from nltk.collocations import *

# %%
sentence = """Hey a clean politicallycorrect joke thats also funny  Thank you Couldnt he gain wealth from his wisdom now What man 
wants most desperately is usually his downfall Reminded me of a great one by Stewart Francis When I was young a genie came to visit me 
He said I could either have a good memory or a long penis I dont remember what I picked Im not sure I understand the punchline Aww 
yeah gtmy reaction httpwwwyoutubecomwatchvXOtkXJc Nice this is a great one Thats pretty good Well done  An angel appears at a 
faculty meeting  And tells the dean that in return for his unselfish and exemplary behavior the Lord will reward him with his 
choice of infinite wealth wisdom or beauty Without hesitating the dean selects infinite wisdomDone says the angel and disappears 
in a cloud of smoke and a bolt of lightning Now all heads turn toward the dean who sits surrounded by a faint halo of light At 
length one of his colleagues whispers Say somethingThe dean sighs and says I should have taken the money
"""

# %%
tokens = nltk.word_tokenize(sentence)

# %%
tagged = nltk.pos_tag(tokens)

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities
# Out:
# Tree('S', [('Hey', 'PRP'), ('a', 'DT'), ('clean', 'JJ'), ('politicallycorrect', 'NN'), ('joke', 'NN'), ('thats', 'NNS'), ('also', 'RB'), ('funny', 'JJ'), ('Thank', 'NNP'), ('you', 'PRP'), ('Couldnt', 'NNP'), ('he', 'PRP'), ('gain', 'NN'), ('wealth', 'NN'), ('from', 'IN'), ('his', 'PRP$'), ('wisdom', 'NN'), ('now', 'RB'), ('What', 'WP'), ('man', 'NN'), ('wants', 'VBZ'), ('most', 'JJS'), ('desperately', 'RB'), ('is', 'VBZ'), ('usually', 'RB'), ('his', 'PRP$'), ('downfall', 'NN'), ('Reminded', 'NNP'), ('me', 'PRP'), ('of', 'IN'), ('a', 'DT'), ('great', 'JJ'), ('one', 'CD'), ('by', 'IN'), Tree('PERSON', [('Stewart', 'NNP'), ('Francis', 'NNP')]), ('When', 'NNP'), ('I', 'NNP'), ('was', 'VBD'), ('young', 'JJ'), ('a', 'DT'), ('genie', 'NN'), ('came', 'VBD'), ('to', 'TO'), ('visit', 'VB'), ('me', 'PRP'), ('He', 'PRP'), ('said', 'VBD'), ('I', 'PRP'), ('could', 'MD'), ('either', 'VB'), ('have', 'VB'), ('a', 'DT'), ('good', 'JJ'), ('memory', 'NN'), ('or', 'CC'), ('a', 'DT'), ('long', 'JJ'), ('pe
# ...

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

finder = BigramCollocationFinder.from_words(tokens)
finder.apply_freq_filter(2) 

# return the 10 n-grams with the highest PMI
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('great', 'one'), ('the', 'dean'), ('a', 'great')]

# %%
from nltk.util import ngrams
n = 5
sixgrams = ngrams(sentence.split(), n)
for grams in sixgrams:
  print grams
# Out:
# ('Hey', 'a', 'clean', 'politicallycorrect', 'joke')
# ('a', 'clean', 'politicallycorrect', 'joke', 'thats')
# ('clean', 'politicallycorrect', 'joke', 'thats', 'also')
# ('politicallycorrect', 'joke', 'thats', 'also', 'funny')
# ('joke', 'thats', 'also', 'funny', 'Thank')
# ('thats', 'also', 'funny', 'Thank', 'you')
# ('also', 'funny', 'Thank', 'you', 'Couldnt')
# ('funny', 'Thank', 'you', 'Couldnt', 'he')
# ('Thank', 'you', 'Couldnt', 'he', 'gain')
# ('you', 'Couldnt', 'he', 'gain', 'wealth')
# ('Couldnt', 'he', 'gain', 'wealth', 'from')
# ('he', 'gain', 'wealth', 'from', 'his')
# ('gain', 'wealth', 'from', 'his', 'wisdom')
# ('wealth', 'from', 'his', 'wisdom', 'now')
# ('from', 'his', 'wisdom', 'now', 'What')
# ('his', 'wisdom', 'now', 'What', 'man')
# ('wisdom', 'now', 'What', 'man', 'wants')
# ('now', 'What', 'man', 'wants', 'most')
# ('What', 'man', 'wants', 'most', 'desperately')
# ('man', 'wants', 'most', 'desperately', 'is')
# ('wants', 'most', 'desperately', 'is', 'usually')
# ...
